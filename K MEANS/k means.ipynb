# %% [markdown]
# ## K-Means
# Common clustering technique, helps to solve many problems efficiently.
# K-Means is an example of Hard Clustering, where every point belongs only to one cluster.
# ### Motivation Problem - Pizza Parlour Study
# Problem Statement Given the list of locations of customers who frequently order Pizza we want to find out optimal locations of Pizza Parlours where they should be opened.
# ![image.png](attachment:image.png)

# %% [markdown]
# Step-1 : Initialise Pizza Parlour Centers randomly.
# ![image.png](attachment:image.png)

# %% [markdown]
# Step-2 : Assign each customer to its nearest Pizza Center.
# ![image.png](attachment:image.png)

# %% [markdown]
# Step-3 : Update the Center Location by taking mean of customers assigned to it.
# ![image.png](attachment:image.png)

# %% [markdown]
# Step-4 : Repeat Steps 2 and 3 Until Convergence.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## K-Means Algorithm
# Input Data : X = {x1,...,xN}
#
# Goal : Partition the data among some K number of clusters. Let us assume K is known to us.
#
# Let µk denote the center of Kth Cluster (uk will be vector)
#
# So we need to ﬁnd an assignment of data points to clusters, as well as a set of cluster centers{µk}, such that the sum of the squares of the distances of each data point to its closest cluster center µk, is a minimum.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Implementation

# %%
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.datasets import make_blobs

# %%
x,y =make_blobs(n_samples=500,n_features=2,centers=5,random_state=3)

# %%
plt.figure(0)
plt.grid(True)
plt.scatter(x[:,0],x[:,1])
plt.show()

# %%
k=5
colors=["red","yellow","blue","green","orange"]

clusters={}

for i in range(k):
    center = 10*(2*np.random.random((x.shape[1],))-1)
    points=[]
    
    cluster={
        'center':center,
        'points':points,
        'color':colors[i]
    }
    
    clusters[i]=cluster

# %%
clusters
# Out:
# {0: {'center': array([ 3.82991884, -6.84164907]),
#   'points': [],
#   'color': 'red'},
#  1: {'center': array([-1.51417449,  8.7772861 ]),
#   'points': [],
#   'color': 'yellow'},
#  2: {'center': array([-2.92526489,  7.15040583]),
#   'points': [],
#   'color': 'blue'},
#  3: {'center': array([ 3.70210702, -9.75394584]),
#   'points': [],
#   'color': 'green'},
#  4: {'center': array([7.29510921, 2.69243981]),
#   'points': [],
#   'color': 'orange'}}

# %%
def distance(v1,v2):
    return np.sqrt(np.sum((v1-v2)**2))

# %%
# Assign every data point to one of the clusters
def assignPointToClusters(clusters): #E-Step
    for i in range(x.shape[0]):
        curren_x=x[i]
        dist=[]
        for j in range(k):
            d=distance(curren_x,clusters[j]['center'])
            dist.append(d)
        
        
        current_cluster =np.argmin(dist)
        clusters[current_cluster]['points'].append(curren_x)

        
def updateClusters(clusters): # M-Step -> We update every cluster center according to the mean of the points 
        for kx in range(k):
            pts=np.array(clusters[kx]['points'])
            
            if pts.shape[0]>0:
                new_u=pts.mean(axis=0)
                clusters[kx]['center']=new_u
                clusters[kx]['points']=[]
    
def plotClusters(clusters):
    for kx in range(k):
        pts=np.array(clusters[kx]['points'])
        print(pts.shape)
        try:
            plt.scatter(pts[:,0],pts[:,1],color=clusters[kx]['color'])
        except:
            pass
        
        
        uk=clusters[kx]['center']
        plt.scatter(uk[0],uk[1],color='black',marker="*")

# %%
assignPointToClusters(clusters)
plotClusters(clusters)
# Out:
# (95, 2)
# (17, 2)
# (270, 2)
# (2, 2)
# (116, 2)

# %%
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (190, 2)
# (34, 2)
# (540, 2)
# (4, 2)
# (232, 2)

# %%
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (124, 2)
# (99, 2)
# (162, 2)
# (15, 2)
# (100, 2)

# %%
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (101, 2)
# (103, 2)
# (148, 2)
# (48, 2)
# (100, 2)

# %%
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (99, 2)
# (103, 2)
# (117, 2)
# (81, 2)
# (100, 2)

# %%
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (102, 2)
# (100, 2)
# (101, 2)
# (97, 2)
# (100, 2)

# %%
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (103, 2)
# (100, 2)
# (98, 2)
# (99, 2)
# (100, 2)

# %%
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (103, 2)
# (100, 2)
# (98, 2)
# (99, 2)
# (100, 2)

# %%
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (103, 2)
# (100, 2)
# (98, 2)
# (99, 2)
# (100, 2)
